# %%
<h3>Import useful librairies and load csv file created previously</h3>

# %%
import pandas as pd
import numpy as np

# %%
dt = pd.read_json("fetchedTweets.json")
dt
# Out:
#             username                                              tweet  \
# 0            admzawa  @SherazadeSmh Y a Bcp de folle on le sait tqt ...
# 1     zipetteenfolie  Le mec qui a inventé la depression viens discu...
# 2            Tej4s27                     Post Travis concert depression
# 3           ssclim77  Ce qu'une dépression peut faire à ta santé aus...
# 4            koruxy1  @nominomm si elle était en depression ca expli...
# ..               ...                                                ...
# 175   Peguy_Certifie  @ActuFoot_ 😂😂😂😂😂😂😂😂😂😂😂😂😂\n\nLA DEPRESSION VA T...
# 176           iwisxh  Vous voyez ça ? Ça m’écœure. Je me bâts depuis...
# 177  MonaRodriguezzz                           Post vacation depression
# 178        kindormad  @Baby_Princess_L Est ce que j’ai dit ça même? ...
# 179   laTrompette_fr  Donner des médicaments aux personnes souffrant...
#
#                          date                   name  \
# 0   2025-10-20 18:50:00+00:00                 Adam🇵🇸
# 1   2025-10-20 18:49:21+00:00                3pm.mvt
# 2   2025-10-20 18:48:00+00:00                   kami
# 3   2025-10-20 18:47:45+00:00                 Moh 🇲🇦
# 4   2025-10-20 18:40:21+00:00                 koruxy
# ..                        ...                    ...
# 175 2025-10-20 13:34:51+00:00  💀 𝐌𝐑. 𝐓 𝐎 𝐍 𝐓 𝐈 𝐍 𝐄 🩸
# 176 2025-10-20 13:34:48+00:00                   ❯❯❯❯
# 177 2025-10-20 13:34:47+00:00           Ms Rodriguez
# 178 2025-10-20 13:34:33+00:00                  Abe 🍉
# 179 2025-10-20 13:34:24+00:00         laTrompette.fr
#
#                           createdAt  followers  following
# 0    Tue May 17 19:16:46 +0000 2022         14        129
# 1    Tue Jan 01 14:37:58 +0000 2019        284       1053
# 2    Sat Jan 20 08:02:37 +0000 2024        726        397
# 3    Mon Dec 16 10:46:56 +0000 2024        838        458
# 4    Mon Sep 19 06:38:06 +0000 2022         40        146
# ..                              ...        ...        ...
# 175  Fri Oct 20 19:07:56 +0000 2017      42717        470
# 176  Wed Aug 28 11:40:51 +0000 2019        158        175
# 177  Sat Aug 24 23:25:43 +0000 2019        367        305
# 178  Thu May 08 20:41:43 +0000 2014        671        560
# 179  Mon Aug 15 08:31:08 +0000 2016        492        162
#
# [180 rows x 7 columns]

# %% [markdown]
# <h3>Let's remove the unnecessary text format</h3>

# %%
import emoji

# %%
dt["tweet"] = dt['tweet'].str.replace("\n", "")

# %%
dt["tweet"] = dt["tweet"].apply(lambda x : emoji.replace_emoji(x, ""))

# %%
dt["tweet"] = dt["tweet"].str.replace(r"http\S+|@\S+|#\S+", "", regex=True)
dt
# Out:
#             username                                              tweet  \
# 0            admzawa   Y a Bcp de folle on le sait tqt pas pas besoi...
# 1     zipetteenfolie  Le mec qui a inventé la depression viens discu...
# 2            Tej4s27                     Post Travis concert depression
# 3           ssclim77  Ce qu'une dépression peut faire à ta santé aus...
# 4            koruxy1   si elle était en depression ca explique les t...
# ..               ...                                                ...
# 175   Peguy_Certifie                     LA DEPRESSION VA TUER CE GOSSE
# 176           iwisxh  Vous voyez ça ? Ça m’écœure. Je me bâts depuis...
# 177  MonaRodriguezzz                           Post vacation depression
# 178        kindormad   Est ce que j’ai dit ça même? J’étais certaine...
# 179   laTrompette_fr  Donner des médicaments aux personnes souffrant...
#
#                          date                   name  \
# 0   2025-10-20 18:50:00+00:00                 Adam🇵🇸
# 1   2025-10-20 18:49:21+00:00                3pm.mvt
# 2   2025-10-20 18:48:00+00:00                   kami
# 3   2025-10-20 18:47:45+00:00                 Moh 🇲🇦
# 4   2025-10-20 18:40:21+00:00                 koruxy
# ..                        ...                    ...
# 175 2025-10-20 13:34:51+00:00  💀 𝐌𝐑. 𝐓 𝐎 𝐍 𝐓 𝐈 𝐍 𝐄 🩸
# 176 2025-10-20 13:34:48+00:00                   ❯❯❯❯
# 177 2025-10-20 13:34:47+00:00           Ms Rodriguez
# 178 2025-10-20 13:34:33+00:00                  Abe 🍉
# 179 2025-10-20 13:34:24+00:00         laTrompette.fr
#
#                           createdAt  followers  following
# 0    Tue May 17 19:16:46 +0000 2022         14        129
# 1    Tue Jan 01 14:37:58 +0000 2019        284       1053
# 2    Sat Jan 20 08:02:37 +0000 2024        726        397
# 3    Mon Dec 16 10:46:56 +0000 2024        838        458
# 4    Mon Sep 19 06:38:06 +0000 2022         40        146
# ..                              ...        ...        ...
# 175  Fri Oct 20 19:07:56 +0000 2017      42717        470
# 176  Wed Aug 28 11:40:51 +0000 2019        158        175
# 177  Sat Aug 24 23:25:43 +0000 2019        367        305
# 178  Thu May 08 20:41:43 +0000 2014        671        560
# 179  Mon Aug 15 08:31:08 +0000 2016        492        162
#
# [180 rows x 7 columns]

# %% [markdown]
# <h3>Now le's work on the date and time column</h3>

# %%
dt.insert(2,"day", 0)
dt.insert(3, "month", 0)
dt.insert(4,"year", 0)
dt.insert(5,"hour",0)
dt.insert(8, "creation",0)

# %%
# All the dates are written the same way : 'Day Month Day(digit)' & at the end the year
# So the format is the same : 3 letters for the day + " " + 3 letters for the month + " " + 2 digits for the day
# We want to export the year for the date to the year column created previously

# %%
dt['date'] = dt['date'].dt.strftime('%Y-%m-%d %H:%M:%S %Z')  #convert a datetime into a str

# %%
dt.date = dt.date.str.replace(" UTC", "")

# %%
dt["hour"] = dt['date'].str[11:16]
dt["year"] = dt["date"].str[0:4]
dt['day'] = dt['date'].str[8:10]
dt.month = dt.date.str[5:7]

dt
# Out:
#             username                                              tweet day  \
# 0            admzawa   Y a Bcp de folle on le sait tqt pas pas besoi...  20
# 1     zipetteenfolie  Le mec qui a inventé la depression viens discu...  20
# 2            Tej4s27                     Post Travis concert depression  20
# 3           ssclim77  Ce qu'une dépression peut faire à ta santé aus...  20
# 4            koruxy1   si elle était en depression ca explique les t...  20
# ..               ...                                                ...  ..
# 175   Peguy_Certifie                     LA DEPRESSION VA TUER CE GOSSE  20
# 176           iwisxh  Vous voyez ça ? Ça m’écœure. Je me bâts depuis...  20
# 177  MonaRodriguezzz                           Post vacation depression  20
# 178        kindormad   Est ce que j’ai dit ça même? J’étais certaine...  20
# 179   laTrompette_fr  Donner des médicaments aux personnes souffrant...  20
#
#     month  year   hour                 date                   name  creation  \
# 0      10  2025  18:50  2025-10-20 18:50:00                 Adam🇵🇸         0
# 1      10  2025  18:49  2025-10-20 18:49:21                3pm.mvt         0
# 2      10  2025  18:48  2025-10-20 18:48:00                   kami         0
# 3      10  2025  18:47  2025-10-20 18:47:45                 Moh 🇲🇦         0
# 4      10  2025  18:40  2025-10-20 18:40:21                 koruxy         0
# ..    ...   ...    ...                  ...                    ...       ...
# 175    10  2025  13:34  2025-10-20 13:34:51  💀 𝐌𝐑. 𝐓 𝐎 𝐍 𝐓 𝐈 𝐍 𝐄 🩸         0
# 176    10  2025  13:34  2025-10-20 13:34:48                   ❯❯❯❯         0
# 177    10  2025  13:34  2025-10-20 13:34:47           Ms Rodriguez         0
# 178    10  2025  13:34  2025-10-20 13:34:33                  Abe 🍉         0
# 179    10  2025  13:34  2025-10-20 13:34:24         laTrompette.fr         0
#
#                           createdAt  followers  following
# 0    Tue May 17 19:16:46 +0000 2022         14        129
# 1    Tue Jan 01 14:37:58 +0000 2019        284       1053
# 2    Sat Jan 20 08:02:37 +0000 2024        726        397
# 3    Mon Dec 16 10:46:56 +0000 2024        838        458
# 4    Mon Sep 19 06:38:06 +0000 2022         40        146
# ..                              ...        ...        ...
# 175  Fri Oct 20 19:07:56 +0000 2017      42717        470
# 176  Wed Aug 28 11:40:51 +0000 2019        158        175
# 177  Sat Aug 24 23:25:43 +0000 2019        367        305
# 178  Thu May 08 20:41:43 +0000 2014        671        560
# 179  Mon Aug 15 08:31:08 +0000 2016        492        162
#
# [180 rows x 12 columns]

# %%
dt.drop("date", axis="columns", inplace=True)

# %%
dt.dtypes
# Out:
# username     object
# tweet        object
# day          object
# month        object
# year         object
# hour         object
# name         object
# creation      int64
# createdAt    object
# followers     int64
# following     int64
# dtype: object

# %%
dt.creation = dt.createdAt.str.slice(start=4, stop=10) + " " + dt.createdAt.str.slice(-4)

# %%
dt.drop("createdAt", axis="columns", inplace=True)
dt
# Out:
#             username                                              tweet day  \
# 0            admzawa   Y a Bcp de folle on le sait tqt pas pas besoi...  20
# 1     zipetteenfolie  Le mec qui a inventé la depression viens discu...  20
# 2            Tej4s27                     Post Travis concert depression  20
# 3           ssclim77  Ce qu'une dépression peut faire à ta santé aus...  20
# 4            koruxy1   si elle était en depression ca explique les t...  20
# ..               ...                                                ...  ..
# 175   Peguy_Certifie                     LA DEPRESSION VA TUER CE GOSSE  20
# 176           iwisxh  Vous voyez ça ? Ça m’écœure. Je me bâts depuis...  20
# 177  MonaRodriguezzz                           Post vacation depression  20
# 178        kindormad   Est ce que j’ai dit ça même? J’étais certaine...  20
# 179   laTrompette_fr  Donner des médicaments aux personnes souffrant...  20
#
#     month  year   hour                   name     creation  followers  \
# 0      10  2025  18:50                 Adam🇵🇸  May 17 2022         14
# 1      10  2025  18:49                3pm.mvt  Jan 01 2019        284
# 2      10  2025  18:48                   kami  Jan 20 2024        726
# 3      10  2025  18:47                 Moh 🇲🇦  Dec 16 2024        838
# 4      10  2025  18:40                 koruxy  Sep 19 2022         40
# ..    ...   ...    ...                    ...          ...        ...
# 175    10  2025  13:34  💀 𝐌𝐑. 𝐓 𝐎 𝐍 𝐓 𝐈 𝐍 𝐄 🩸  Oct 20 2017      42717
# 176    10  2025  13:34                   ❯❯❯❯  Aug 28 2019        158
# 177    10  2025  13:34           Ms Rodriguez  Aug 24 2019        367
# 178    10  2025  13:34                  Abe 🍉  May 08 2014        671
# 179    10  2025  13:34         laTrompette.fr  Aug 15 2016        492
#
#      following
# 0          129
# 1         1053
# 2          397
# 3          458
# 4          146
# ..         ...
# 175        470
# 176        175
# 177        305
# 178        560
# 179        162
#
# [180 rows x 10 columns]

# %%
dt = dt.astype ({
        "day":int,
        "year":int,
        "month":int
})

# %%
dt.to_json("../ressource/cleanedTweets.json", orient="records")
